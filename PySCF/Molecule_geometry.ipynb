# %%
from pyscf import gto

# %% [markdown]
# # Задаємо георметрію молекули

# %% [markdown]
# ## Задали координати в Ангстемах

# %%
mol = gto.M(atom='''
                 O       -2.60858        0.82218        0.00000
                 H       -1.63858        0.82218        0.00000
                 H       -2.93191        1.69020       -0.28792
                 ''',
            charge=0,
            spin=0,      
            unit='Angstrom')

# %% [markdown]
# # Координати в Борах

# %%
mol.atom_coords()
# Out:
# array([[-4.92950177,  1.55369503,  0.        ],
#        [-3.09646743,  1.55369503,  0.        ],
#        [-5.54050692,  3.1940151 , -0.54408995]])
