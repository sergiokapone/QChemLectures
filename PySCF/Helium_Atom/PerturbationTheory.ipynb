# %% [markdown]
# # Теорія збурень
#
# Основна ідея теорії збурень --- всі взаємодії в системі можна умовно розділити на "основні" і "збурення", --- гамільтоніан системи можна представити у вигляді:
# \begin{equation*}
#     \hat{H} = \hat{H}^0 + \hat{V},
# \end{equation*}
# де  $\hat{H}^0$ - "незбурений" гамільтоніан:
# \begin{equation*}
#     \hat{H}^0\psi_n^{(0)} = E_n\psi_n^{(0)}.
# \end{equation*}
# Функції $\{\psi_n^{(0)}\}$ --- орбіталі.
#
# $\hat{V}$ - збурення.
#
# Перше наближення теорії збурень:
# \begin{equation*}
#     E_n = E_n^{(0)} + \left\langle\psi_n^{(0)}|\hat{V}|\psi_n^{(0)}\right\rangle, \quad
#     \psi_n = \psi_n^{(0)} + \sum\limits_{\substack{m\\m \neq n}} \frac{\left\langle\psi_n^{(0)}|\hat{V}|\psi_m^{(0)}\right\rangle}{E_n^{(0)} - E_m^{(0)}} \psi_m^{(0)}.
# \end{equation*}

# %%
from sympy import symbols, exp, cos, sin, sqrt, pi, integrate, simplify, oo, Abs, Q, refine, diff, Rational
from sympy.physics.hydrogen import Psi_nlm, E_nl

# %%
Z, n = symbols('Z n', positive=True)

# %%
E = 2 * E_nl(1, Z) + Rational(5,8) * Z
E
# Out:
# -Z**2 + 5*Z/8

# %%
E.subs(Z, 2).evalf()
# Out:
# -2.75000000000000
